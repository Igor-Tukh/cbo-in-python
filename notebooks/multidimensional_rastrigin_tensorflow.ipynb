# %%
import os
import sys
sys.path.append(os.pardir)

# %%
import tensorflow as tf
import numpy as np

# %%
from src.tensorflow.minimize import minimize
from src.tensorflow.functions import rastrigin_c
from src.tensorflow.distributions import Normal
from src.tensorflow.visualizations import visualize_trajectory_convergence

# %%
minimizer, trajectory = minimize(rastrigin_c(2.5), dimensionality=1, n_particles=100, time_horizon=2, 
                                  return_trajectory=True, optimizer_config = {
                                      'alpha': 1000,
                                      'sigma': 0.2,
                                  },
                                  initial_distribution=Normal(2, 3))
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 101/101 [00:11<00:00,  8.64it/s]

# %%
visualize_trajectory_convergence(trajectory, 0, display_exponent=True, exp_sigma=0.2)

# %%
minimizer, trajectory = minimize(rastrigin_c(2.5), dimensionality=2, n_particles=100, time_horizon=2, 
                                  return_trajectory=True, optimizer_config = {
                                      'alpha': 1000,
                                      'sigma': 0.2,
                                  },
                                  initial_distribution=Normal(2, 3))
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 101/101 [00:11<00:00,  8.63it/s]

# %%
visualize_trajectory_convergence(trajectory, tf.zeros(2), display_exponent=True, exp_sigma=0.2)

# %%
minimizer, trajectory = minimize(rastrigin_c(2.5), dimensionality=4, n_particles=100, time_horizon=2, 
                                  return_trajectory=True, optimizer_config = {
                                      'alpha': 1000,
                                      'sigma': 0.2,
                                  },
                                  initial_distribution=Normal(2, 3))
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 101/101 [00:11<00:00,  8.83it/s]

# %%
visualize_trajectory_convergence(trajectory, tf.zeros(4), display_exponent=True, exp_sigma=0.2)

# %%
minimizer, trajectory = minimize(rastrigin_c(2.5), dimensionality=8, n_particles=100, time_horizon=2, 
                                  return_trajectory=True, optimizer_config = {
                                      'alpha': 1000,
                                      'sigma': 0.2,
                                  },
                                  initial_distribution=Normal(2, 3))
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 101/101 [00:11<00:00,  8.83it/s]

# %%
visualize_trajectory_convergence(trajectory, tf.zeros(8), display_exponent=True, exp_sigma=0.2)

# %%
minimizer, trajectory = minimize(rastrigin_c(2.5), dimensionality=12, n_particles=200, time_horizon=2, 
                                  return_trajectory=True, optimizer_config = {
                                      'alpha': 2000,
                                      'sigma': 0.2,
                                  },
                                  initial_distribution=Normal(2, 3))
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 101/101 [00:22<00:00,  4.48it/s]

# %%
visualize_trajectory_convergence(trajectory, tf.zeros(12), display_exponent=True, exp_sigma=0.2)

# %%
minimizer, trajectory = minimize(rastrigin_c(2.5), dimensionality=16, n_particles=200, time_horizon=2, 
                                  return_trajectory=True, optimizer_config = {
                                      'alpha': 2000,
                                      'sigma': 0.2,
                                  },
                                  initial_distribution=Normal(2, 3))
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 101/101 [00:22<00:00,  4.40it/s]

# %%
visualize_trajectory_convergence(trajectory, tf.zeros(16), display_exponent=True, exp_sigma=0.2)
